# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %matplotlib notebook

# %%
# Global Settings (color of bars, etc.)
os.chdir("C:/workshops/temp_Dynamic Charts")
df = pd.read_csv('acumendata.csv').dropna()
bar_colors = ['#1F497D', '#f58231', '#008080', '#e6beff', '#aa6e28', '#fffac8', '#800000', '#aaffc3', '#808000', '#ffd8b1', '#000080', '#808080', '#FFFFFF', '#000000']

# Parameters Toggle Here:
topic = "Race"
x_label = ['Race1', 'Race2','Race3']
charttype = 'percent'

# Pre-Processing
summary = df.groupby(['Quarter', 'Race']).size().reset_index(name='Count')
summary_pivot = summary.pivot_table(index='Quarter', columns='Race', values='Count')
quarter_totals = pivoted.sum(axis=1)
percentages = pivoted.divide(quarter_totals, axis=0)
percentages = percentages.applymap(lambda x: f"{x:.1%}")
percentages.iloc[:,:] = percentages.iloc[:,:].apply(lambda x: x.str.rstrip('%').astype('float'), axis=1)
# col_names = list(summary_pivot.columns)
# col_names_new = ['Female','Male']
# columndict = dict(zip(col_names, col_names_new))
# summary_pivot = summary_pivot.rename(columns = columndict)

if charttype == 'count':
    y_max = 1200
    y_label = "Value Counts"
    data = summary_pivot
else:
    y_max = 100
    y_label = "Percent"
    data = percentages
chartarray = np.array(data)
# Out:
#   File "C:\Users\m1321\AppData\Local\Temp\ipykernel_2620\257412420.py", line 8
#     x_label = ['Race1', 'Race2','Race3']
#     ^
# SyntaxError: invalid syntax

# %%
fig, ax = plt.subplots()
ax.set_ylabel(y_label)
ax.set_ylim(0, y_max)
axisarray = np.array(['{}'.format(val) for val in chartarray[0]])
bars = ax.bar(axisarray, chartarray[0], align='center')

def update(i):
    for j, bar in enumerate(bars):
        bar.set_height(chartarray[i, j])
        for t in ax.texts:
            if np.allclose(t.get_position(), [bar.get_x() + bar.get_width() / 2, chartarray[i-1, j]]):
                t.set_position((bar.get_x() + bar.get_width() / 2, bar.get_height()))
                t.set_text(round(bar.get_height(), 2))
                t.set_visible(True)
        if i == 0:
            ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),round(bar.get_height(), 2), ha='center', va='bottom')
    ax.set_xticklabels(x_label)
    ax.set_title(f'Quarter {i+1} {topic} Distribution Animation')
    return bars

plt.tick_params(axis='x', which='both', bottom=False, top=False)
fig.set_facecolor('#f2f2f2')
ax.grid(axis='y', linestyle='--', alpha=0.7, color='#d9d9d9')

for i, bar in enumerate(bars):
    bar.set_color(bar_colors[i % len(bar_colors)])
    bar.set_edgecolor('white')

# Display the animation
anim = FuncAnimation(fig, update, frames=range(0, 12), interval=1000, blit=True)
plt.show()
anim.save('sex_distribution.gif', writer='imagemagick')
# Out:
# <img src="data:image/png;base64,..." width="640">
# MovieWriter imagemagick unavailable; using Pillow instead.
# C:\Users\m1321\AppData\Local\Temp\ipykernel_2620\4200605890.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x_label)

# %%
import pandas as pd

# Assuming your DataFrame is named `df` and looks something like this:
#   Quarter  Race
# 0       1     1
# 1       1     2
# 2       1     2
# 3       2     1
# 4       2     1
# 5       2     3
# ...

# Group the data by Quarter and Race, and count the number of occurrences in each group
counts = df.groupby(['Quarter', 'Race']).size().reset_index(name='count')

# Pivot the data so that Race becomes the column names
pivoted = counts.pivot(index='Quarter', columns='Race', values='count')

# Calculate the total count for each quarter
quarter_totals = pivoted.sum(axis=1)

# Divide each race count by the quarter total to get the percentage for each race in each quarter
percentages = pivoted.divide(quarter_totals, axis=0)

# Rename the columns to include 'Race' and convert the percentages to strings with a percent sign
percentages.columns = [f"Race{col}_percentage" for col in percentages.columns]
percentages = percentages.applymap(lambda x: f"{x:.2%}")

# Display the result
print(percentages)
# Out:
#         Race1.0_percentage Race2.0_percentage Race3.0_percentage
# Quarter
# 1                   55.98%             27.74%             16.28%
# 2                   55.09%             28.24%             16.67%
# 3                   55.52%             28.99%             15.48%
# 4                   55.80%             29.49%             14.71%
# 5                   55.44%             29.40%             15.17%
# 6                   55.66%             29.16%             15.18%
# 7                   55.54%             29.08%             15.39%
# 8                   55.58%             29.07%             15.34%
# 9                   55.71%             29.00%             15.29%
# 10                  55.76%             29.07%             15.17%
# 11                  55.65%             29.18%             15.17%
# 12                  55.63%             29.10%             15.27%

# %%
quarter_totals = pivoted.sum(axis=1)

# Divide each race count by the quarter total to get the percentage for each race in each quarter
percentages = pivoted.divide(quarter_totals, axis=0)

# Rename the columns to include 'Race' and convert the percentages to strings with a percent sign
percentages = percentages.applymap(lambda x: f"{x:.2%}")

# %%
percentages
# Out:
# Race        1.0     2.0     3.0
# Quarter
# 1        55.98%  27.74%  16.28%
# 2        55.09%  28.24%  16.67%
# 3        55.52%  28.99%  15.48%
# 4        55.80%  29.49%  14.71%
# 5        55.44%  29.40%  15.17%
# 6        55.66%  29.16%  15.18%
# 7        55.54%  29.08%  15.39%
# 8        55.58%  29.07%  15.34%
# 9        55.71%  29.00%  15.29%
# 10       55.76%  29.07%  15.17%
# 11       55.65%  29.18%  15.17%
# 12       55.63%  29.10%  15.27%
